# %%
pip install git+https://github.com/LucianoPereiraValenzuela/ECC_2025_testing.git
# Out:
# ...
#   Cloning https://github.com/LucianoPereiraValenzuela/ECC_2025_testing.git to /tmp/pip-req-build-_cdm_si2
#   Running command git clone --filter=blob:none --quiet https://github.com/LucianoPereiraValenzuela/ECC_2025_testing.git /tmp/pip-req-build-_cdm_si2
#   Resolved https://github.com/LucianoPereiraValenzuela/ECC_2025_testing.git to commit c6803bcf632a73eb94a6e8663007c8a3c26e88de
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 41.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 35.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 46.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.3/343.3 kB 16.7 MB/s eta 0:00:00
# ...

# %%
import numpy as np
from qiskit import QuantumCircuit
from testing import test_3

# %% [markdown]
# La subrutina más importante del algoritmo de Shor es la transformada cuántica de Fourier. Esta permite aplicar la transformada discreta de Fourier a un estado cuántico, y es implementada por el siguiente circuito:
#
# (poner imagen acá)

# %% [markdown]
# Cree una función llamada ``Fourier(n)`` cuyo argumento es el número de qubits $n$ y que retorne el circuito cuántico de la transformada de Fourier de $n$ qubits.

# %%
def Fourier(n):
    qc = QuantumCircuit(n)
    ### Escribe tu codigo acá ###

    #######
    return qc

# %%
qc = Fourier( 2 )
qc.draw('mpl')

# %%
test_3( Fourier )
# Out:
# Felicidades, tu solución es correcta!
